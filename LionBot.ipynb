# %%
import telebot
from telebot import types

# %%
user_data = {}
class User:
    def __init__(self):
        self.card = ''
        self.fav_pr_1 = ''
        self.fav_pr_2 = ''
        self.fav_pr_3 = ''

# %%
bot = telebot.TeleBot('1225129237:AAE2kx6dq1vuM22PfcD0Md0lyZv3cl1Dbbk')

# %%
user = User()
@bot.message_handler(commands=['start'])
def start_message(message):
    msg = bot.send_message(message.chat.id, ' hey, I am Lenta line, enter your card code')
    bot.register_next_step_handler(msg, get_card_number)

@bot.message_handler(content_types=['text'])
def get_card_number(message):
    try:
        
        user.card = message.text
 
        msg = bot.send_message(message.chat.id, "ur fav product #1")
        bot.register_next_step_handler(msg, get_fav_products_1)
    except Exception as e:
        bot.reply_to(message, 'oooops')
    

    
@bot.message_handler(content_types=['text'])
def get_fav_products_1(message):
    try:
        
        user.fav_pr_1 = message.text
 
        msg = bot.send_message(message.chat.id, "ur fav product #2")
        bot.register_next_step_handler(msg, get_fav_products_2)
    except Exception as e:
        bot.reply_to(message, 'oooops')
#     fp_1  = message.text 
#     print(fp_1)
#     bot.send_message(message.chat.id, ' more')
#     fp_2  = message.text 
#     print(fp_2)

@bot.message_handler(content_types=['text'])
def get_fav_products_2(message):
    try:
        
        user.fav_pr_2 = message.text
 
        msg = bot.send_message(message.chat.id, "ur fav product #3")
        bot.register_next_step_handler(msg, get_fav_products_3)
    except Exception as e:
        bot.reply_to(message, 'oooops')

        
@bot.message_handler(content_types=['text'])
def get_fav_products_3(message):
    try:
        
        user.fav_pr_3 = message.text
 
        msg = bot.send_message(message.chat.id, "thanx")
        bot.register_next_step_handler(msg, delivery_type)
    except Exception as e:
        bot.reply_to(message, 'oooops')


        

def delivery_type(message):
    markup = types.ReplyKeyboardMarkup(one_time_keyboard=True, resize_keyboard=True)
    itembtn1 = types.KeyboardButton('Pickup')
    itembtn2 = types.KeyboardButton('Delivery')

    markup.add(itembtn1, itembtn2) 
    msg = bot.send_message(message.chat.id, 'How to deliver?', reply_markup=markup)
    bot.register_next_step_handler(msg, print_m)

# @bot.message_handler(content_types=['text'])
# def print_m(message):
#     if message.text == 'Pickup':
#         markup = types.ReplyKeyboardMarkup(one_time_keyboard=True, resize_keyboard=True)
#         itembtn1 = types.KeyboardButton('YES')
#         itembtn2 = types.KeyboardButton('NO')

#         markup.add(itembtn1, itembtn2) 
#         msg = bot.send_message(message.chat.id, "pickup from ur fav shop?", reply_markup=markup)
#         bot.register_next_step_handler(msg, if_pickup)
        
#     elif message.text == 'Delivery':
#         msg = bot.send_message(message.chat.id, "adress plz")
#         bot.register_next_step_handler(msg, if_delivery)

# @bot.message_handler(content_types=['text'])
# def if_pickup(message):
#     if message.text == 'NO':
#         msg = bot.send_message(message.chat.id, "enter the adress of ur shop")
#         bot.register_next_step_handler(msg, shop_adress)
#     elif message.text == 'YES':
#         msg = bot.send_message(message.chat.id, "thanx")
#         bot.register_next_step_handler(msg, end)

# @bot.message_handler(content_types=['text'])
# def if_delivery(message):
#     print(message.text)
#     msg = bot.send_message(message.chat.id, "thanx")
#     bot.register_next_step_handler(msg, end)
        
    
# @bot.message_handler(content_types=['text'])
# def shop_adress(message):
#     print(message.text)
#     msg = bot.send_message(message.chat.id, "thanx")
#     bot.register_next_step_handler(msg, end)
# def end(message):
#     bot.send_message(message.chat.id, "finit a la comedia.")
bot.polling(none_stop=True, interval=0)
# Out:
# 2020-09-26 15:42:40,571 (util.py:75 WorkerThread2) ERROR - TeleBot: "ReadTimeout occurred, args=(ReadTimeoutError("HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=3.5)"),)
# Traceback (most recent call last):
#   File "/Users/Anna.Rudenko/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/requests/packages/urllib3/connectionpool.py", line 341, in _make_request
#     self._validate_conn(conn)
#   File "/Users/Anna.Rudenko/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/requests/packages/urllib3/connectionpool.py", line 761, in _validate_conn
#     conn.connect()
#   File "/Users/Anna.Rudenko/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/requests/packages/urllib3/connection.py", line 234, in connect
#     self.sock = ssl_wrap_socket(conn, self.key_file, self.cert_file,
#   File "/Users/Anna.Rudenko/opt/anaconda3/envs/myenv/lib/python3.8/site-packages/requests/packages/urllib3/util/ssl_.py", line 279, in ssl_wrap_socket
# ...

# %%
user.card, user.fav_pr_1, user.fav_pr_2,  user.fav_pr_3
# Out:
# ('1234', 'lime', 'jin', 'cucumbers')

# %%
@bot.message_handler(content_types=['text'])
def get_text_messages(message):
    if message.text == "\\hello":
        bot.send_message(message.from_user.id, "Привет, сейчас я расскажу тебе гороскоп на сегодня.")
        show_zodiac_buttons_on(message)
    elif message.text == "/help":
        bot.send_message(message.from_user.id, "Напиши \\hello")
    else:
        bot.send_message(message.from_user.id, "Я тебя не понимаю. Напиши /help.")
        

bot.polling(none_stop=True, interval=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-f7d820df777b> in <module>
# ----> 1 @bot.message_handler(content_types=['text'])
#       2 def get_text_messages(message):
#       3     if message.text == "\\hello":
#       4         bot.send_message(message.from_user.id, "Привет, сейчас я расскажу тебе гороскоп на сегодня.")
#       5         show_zodiac_buttons_on(message)
#
# AttributeError: 'TeleBot' object has no attribute 'message_handler'

# %%
    card_number  = message.text 
    print(card_number)
